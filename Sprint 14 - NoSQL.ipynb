# %% [markdown]
# # <font color='#d50283'>IT Academy - Data Science Itinerary</font>
# ## Sprint 14 Task 1 - Create NoSQL database
# ### Assignment by: Kat Weissman
#
# #### Objectives:
#
# - Use a MongoDB database
# - Interconnect the MongoDB database with Python.

# %% [markdown]
# *Recommended learning resources:*
# - https://www.mongodb.com/nosql-explained
# - https://www.w3schools.com/python/python_mongodb_getstarted.asp
# - https://docs.mongodb.com/manual/tutorial/

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# ### Level 1
# ### Exercise 1
# Create a NoSQL database using MongoDB. Add some sample data to help you verify that you are able to process the information in a basic way.

# %% [markdown]
# I created a MongoDB Atlas account and loaded sample data following the tutorial on the webpages https://www.mongodb.com/nosql-explained and https://docs.atlas.mongodb.com/sample-data/

# %% [markdown]
# ![Screenshot%202022-02-14%20at%2012.39.13.png](attachment:Screenshot%202022-02-14%20at%2012.39.13.png)

# %% [markdown]
# ### Exercise 2
# Connect the NoSQL database to Python using for example pymongo.
#
# Reference: https://www.kaggle.com/ashishsaxena2209/tutorial-to-use-mongodb-atlas-cloud-service

# %% [markdown]
# Example connection for Python 3.4 or later:
#
# - myclient = mongodb://KatITAcademy:"password"@learning-shard-00-00.xbvwy.mongodb.net:27017,learning-shard-00-01.xbvwy.mongodb.net:27017,learning-shard-00-02.xbvwy.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-znqo68-shard-0&authSource=admin&retryWrites=true&w=majority
#
# Replace "password" with the password for the KatITAcademy user. Replace myFirstDatabase with the name of the database that connections will use by default. Ensure any option params are URL encoded.
#
# In order to do the connection, I used admin as the database.

# %%
myclient = pymongo.MongoClient("mongodb://KatITAcademy:password@learning-shard-00-00.xbvwy.mongodb.net:27017,learning-shard-00-01.xbvwy.mongodb.net:27017,learning-shard-00-02.xbvwy.mongodb.net:27017/admin?ssl=true&replicaSet=atlas-znqo68-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
# Return a list of your system's databases:
print(myclient.list_database_names())
# Out:
# ['sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %% [markdown]
# I will use the database of sample_mflix for this assignment.

# %%
mydb = myclient["sample_mflix"]

# %%
# Return a list of all collections in your database:
print(mydb.list_collection_names())
# Out:
# ['theaters', 'sessions', 'users', 'movies', 'comments']

# %% [markdown]
# I will use the collection "theaters" in the "sample_mflix" database.

# %%
# Find the first document in a collection:
mycol = mydb["theaters"]
x = mycol.find_one()
print(x)
# Out:
# {'_id': ObjectId('59a47286cfa9a3a73e51e72c'), 'theaterId': 1000, 'location': {'address': {'street1': '340 W Market', 'city': 'Bloomington', 'state': 'MN', 'zipcode': '55425'}, 'geo': {'type': 'Point', 'coordinates': [-93.24565, 44.85466]}}}

# %% [markdown]
# ### Level 2
# ### Exercise 1
# Load some simple queries to a Pandas Dataframe.

# %% [markdown]
# My first query will be to create a dataframe of theaters that are in the state of Minnesota, MN.

# %%
myquery = { 'state': 'MN' }
mydoc = mycol.find(myquery)

# %%
for x in mydoc:
    print (x)

# %% [markdown]
# The query is not working as expected, and I will return to this part of the assignment at the end of the course if I have time.

# %% [markdown]
# ### Level 3
# ### Exercise 1
# Generate a statistical summary of the information contained in the database.

# %% [markdown]
# I will return to this part of the assignment at the end of the course if I have time.
